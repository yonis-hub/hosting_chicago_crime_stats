# %%
# importing dependencies
import pandas as pd
from sqlalchemy import create_engine
# need this later when creating sql database
import config

# %%
# read in the dataset and put into a dataframe
chicago_crime_file = "data/chicago_crime_stats.csv"
chicago_crime_file
# Out:
# 'data/chicago_crime_stats.csv'

# %%
chicago_crime_df = pd.read_csv(chicago_crime_file)
# looking at the dataframe
chicago_crime_df
# Out:
#              ID Case Number           Date                     Block  IUCR  \
# 0      12260346    JE102126   1/3/21 13:23     070XX S EGGLESTON AVE   486
# 1      12263464    JE105797    1/3/21 6:59          080XX S YALE AVE   820
# 2      12259990    JE101773    1/3/21 0:20   056XX W WASHINGTON BLVD   486
# 3      12260669    JE102509   1/3/21 20:47        057XX S RACINE AVE  2022
# 4         25702    JE102438   1/3/21 20:09  068XX S STONY ISLAND AVE   110
# ...         ...         ...            ...                       ...   ...
# 53240  12347539    JE207632   4/15/21 0:00        049XX N MENARD AVE  1153
# 53241  12350321    JE211512  3/12/21 10:00       033XX W CARROLL AVE   810
# 53242  12346696    JE207066  4/20/21 19:00        028XX W LYNDALE ST   820
# 53243  12345198    JE205294  4/20/21 23:23        012XX S WABASH AVE   820
# 53244  12344827    JE204873  4/20/21 12:00      081XX S MANISTEE AVE   820
#
#              Primary Type                          Description  \
# 0                 BATTERY              DOMESTIC BATTERY SIMPLE
# 1                   THEFT                       $500 AND UNDER
# 2                 BATTERY              DOMESTIC BATTERY SIMPLE
# 3               NARCOTICS                    POSSESS - COCAINE
# 4                HOMICIDE                  FIRST DEGREE MURDER
# ...                   ...                                  ...
# 53240  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 53241               THEFT                            OVER $500
# 53242               THEFT                       $500 AND UNDER
# 53243               THEFT                       $500 AND UNDER
# 53244               THEFT                       $500 AND UNDER
#
#       Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                APARTMENT   False      True  ...   6.0              68
# 1                RESIDENCE   False     False  ...  17.0              44
# 2                APARTMENT   False      True  ...  29.0              25
# 3                   STREET    True     False  ...  16.0              67
# 4                   STREET   False     False  ...   5.0              43
# ...                    ...     ...       ...  ...   ...             ...
# 53240   GROCERY FOOD STORE   False     False  ...  45.0              11
# 53241            RESIDENCE   False     False  ...  28.0              27
# 53242                ALLEY   False     False  ...   1.0              22
# 53243   SMALL RETAIL STORE    True     False  ...   3.0              33
# 53244               STREET   False     False  ...   7.0              46
#
#        FBI Code  X Coordinate Y Coordinate  Year     Updated On   Latitude  \
# 0           08B     1174496.0    1858251.0  2021  1/16/21 15:49  41.766435
# 1             6     1176011.0    1851718.0  2021  1/16/21 15:49  41.748474
# 2           08B     1138722.0    1900183.0  2021  1/16/21 15:49  41.882224
# 3            18     1169298.0    1866822.0  2021  1/16/21 15:49  41.790069
# 4           01A     1188038.0    1860051.0  2021  1/10/21 15:51  41.771062
# ...         ...           ...          ...   ...            ...        ...
# 53240        11     1136506.0    1932167.0  2021  4/27/21 16:48  41.970032
# 53241         6           NaN          NaN  2021  4/27/21 16:51        NaN
# 53242         6     1157013.0    1914958.0  2021  4/27/21 16:51  41.922417
# 53243         6     1176963.0    1894850.0  2021  4/27/21 16:51  41.866811
# 53244         6     1195918.0    1851506.0  2021  4/27/21 16:51  41.747423
#
#        Longitude                       Location
# 0     -87.635964  (41.766435144, -87.635963997)
# 1     -87.630607  (41.748473982, -87.630606588)
# 2     -87.766076   (41.88222427, -87.766076162)
# 3     -87.654769   (41.79006908, -87.654768679)
# 4     -87.586271  (41.771062488, -87.586270811)
# ...          ...                            ...
# 53240 -87.773447  (41.970031874, -87.773446582)
# 53241        NaN                            NaN
# 53242 -87.698510  (41.922416744, -87.698509633)
# 53243 -87.625817  (41.866810739, -87.625817031)
# 53244 -87.557669  (41.747422937, -87.557668601)
#
# [53245 rows x 22 columns]

# %% [markdown]
# # Transform
# Here we take our dataframe and drop the columns we do not want included.

# %%
# columns we want to keep and include in the new 
chicago_crime_cols = ["ID", "Date", "Primary Type", "Description", "Arrest", "Domestic", "District", "Year", "Latitude",
                     "Longitude"]

# creating a new dataframe of the columns we want to include in our database
chicago_crime_stats_df = chicago_crime_df[chicago_crime_cols].copy()

# %%
# looking at our new dataframe
chicago_crime_stats_df = chicago_crime_stats_df.rename(columns=str.lower)

chicago_crime_stats_df.head()
# Out:
#          id          date primary type              description  arrest  \
# 0  12260346  1/3/21 13:23      BATTERY  DOMESTIC BATTERY SIMPLE   False
# 1  12263464   1/3/21 6:59        THEFT           $500 AND UNDER   False
# 2  12259990   1/3/21 0:20      BATTERY  DOMESTIC BATTERY SIMPLE   False
# 3  12260669  1/3/21 20:47    NARCOTICS        POSSESS - COCAINE    True
# 4     25702  1/3/21 20:09     HOMICIDE      FIRST DEGREE MURDER   False
#
#    domestic  district  year   latitude  longitude
# 0      True         7  2021  41.766435 -87.635964
# 1     False         6  2021  41.748474 -87.630607
# 2      True        15  2021  41.882224 -87.766076
# 3     False         7  2021  41.790069 -87.654769
# 4     False         3  2021  41.771062 -87.586271

# %% [markdown]
# # Limit the dataframe to violent crimes only

# %%
# take only those Primary Type's that are considered violent crimes

# %%
# checking the length of the dataframe
len(chicago_crime_stats_df)
# Out:
# 53245

# %%
# limit dataframe to homicide, battery, assault, robbery, and sex offense
violent_crimes_df = chicago_crime_stats_df.loc[(chicago_crime_stats_df["primary type"]=="HOMICIDE") | 
                                               (chicago_crime_stats_df["primary type"]=="BATTERY") |
                                               (chicago_crime_stats_df["primary type"]=="ASSAULT") |
                                               (chicago_crime_stats_df["primary type"]=="ROBBERY") |
                                               (chicago_crime_stats_df["primary type"]=="SEX OFFENSE")]

# rename primary type as Primary_Type
violent_crimes_df = violent_crimes_df.rename(columns={"primary type": "primary_type"})

# looking at violent crimes only
violent_crimes_df.head()
# Out:
#           id          date primary_type              description  arrest  \
# 0   12260346  1/3/21 13:23      BATTERY  DOMESTIC BATTERY SIMPLE   False
# 2   12259990   1/3/21 0:20      BATTERY  DOMESTIC BATTERY SIMPLE   False
# 4      25702  1/3/21 20:09     HOMICIDE      FIRST DEGREE MURDER   False
# 5   12260241   1/3/21 8:54      ASSAULT                   SIMPLE   False
# 10     25703  1/3/21 21:28     HOMICIDE      FIRST DEGREE MURDER   False
#
#     domestic  district  year   latitude  longitude
# 0       True         7  2021  41.766435 -87.635964
# 2       True        15  2021  41.882224 -87.766076
# 4      False         3  2021  41.771062 -87.586271
# 5      False         4  2021  41.702154 -87.563980
# 10     False         4  2021  41.736660 -87.544454

# %%
# format the date in the first column using datetime
# first need to take the time out of the row
violent_crimes_df["date"] = violent_crimes_df["date"].str.split(" ", 1, expand=True)

# now format the date using datetime
violent_crimes_df["date"] = pd.to_datetime(violent_crimes_df["date"],format="%m/%d/%y")

violent_crimes_df.head()
# Out:
#           id       date primary_type              description  arrest  \
# 0   12260346 2021-01-03      BATTERY  DOMESTIC BATTERY SIMPLE   False
# 2   12259990 2021-01-03      BATTERY  DOMESTIC BATTERY SIMPLE   False
# 4      25702 2021-01-03     HOMICIDE      FIRST DEGREE MURDER   False
# 5   12260241 2021-01-03      ASSAULT                   SIMPLE   False
# 10     25703 2021-01-03     HOMICIDE      FIRST DEGREE MURDER   False
#
#     domestic  district  year   latitude  longitude
# 0       True         7  2021  41.766435 -87.635964
# 2       True        15  2021  41.882224 -87.766076
# 4      False         3  2021  41.771062 -87.586271
# 5      False         4  2021  41.702154 -87.563980
# 10     False         4  2021  41.736660 -87.544454

# %%
# set date as the index for SQL database
violent_crimes_df.set_index("id", inplace=True)
violent_crimes_df.head()
# Out:
#                date primary_type              description  arrest  domestic  \
# id
# 12260346 2021-01-03      BATTERY  DOMESTIC BATTERY SIMPLE   False      True
# 12259990 2021-01-03      BATTERY  DOMESTIC BATTERY SIMPLE   False      True
# 25702    2021-01-03     HOMICIDE      FIRST DEGREE MURDER   False     False
# 12260241 2021-01-03      ASSAULT                   SIMPLE   False     False
# 25703    2021-01-03     HOMICIDE      FIRST DEGREE MURDER   False     False
#
#           district  year   latitude  longitude
# id
# 12260346         7  2021  41.766435 -87.635964
# 12259990        15  2021  41.882224 -87.766076
# 25702            3  2021  41.771062 -87.586271
# 12260241         4  2021  41.702154 -87.563980
# 25703            4  2021  41.736660 -87.544454

# %%
# checking the length of the new dataframe
len(violent_crimes_df)
# Out:
# 17782

# %%
violent_crimes_df= violent_crimes_df.head(10000)
len(violent_crimes_df)
# Out:
# 10000

# %%
#list unique values in the df ['primary_type']
violent_crimes_df.primary_type.unique()
# Out:
# array(['BATTERY', 'HOMICIDE', 'ASSAULT', 'ROBBERY', 'SEX OFFENSE'],
#       dtype=object)

# %%
# checking the data types
print(violent_crimes_df.dtypes)

# %% [markdown]
# # Load the data into SQL Database

# %%
# Create a SQL Database connection
connection_string = f"postgres:{config.password}@localhost:5432/chicago_violent_crimes_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# checking tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
# FATAL:  no pg_hba.conf entry for host "73.164.68.11", user "postgres", database "d4bbdqfrrmiu0v", SSL off
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-16-b6f094733650> in <module>
#       1 # checking tables
# ----> 2 engine.table_names()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in table_names(self, schema, connection)
#    2317         """
#    2318
# -> 2319         with self._optional_conn_ctx_manager(connection) as conn:
#    2320             return self.dialect.get_table_names(conn, schema)
#    2321
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _optional_conn_ctx_manager(self, connection)
#    2087     def _optional_conn_ctx_manager(self, connection=None):
#    2088         if connection is None:
# -> 2089             with self._contextual_connect() as conn:
#    2090                 yield conn
#    2091         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2341             if connection is None:
#    2342                 Connection._handle_dbapi_exception_noconnection(
# -> 2343                     e, dialect, self
#    2344                 )
#    2345             else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1583         elif should_wrap:
#    1584             util.raise_(
# -> 1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#    1587         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
# FATAL:  no pg_hba.conf entry for host "73.164.68.11", user "postgres", database "d4bbdqfrrmiu0v", SSL off
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# load dataframes into database
try:
    violent_crimes_df.to_sql(name="violent_crimes", con=engine, if_exists="append", index=True)
    print("Data loaded successfully")
    
except:
    print("Data has already been loaded to db")
